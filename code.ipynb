# %%
import requests
import pandas as pd

# %%
r = requests.get('https://randomuser.me/api/?results=250')
# r.json()
df = pd.json_normalize(r.json()["results"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   gender                          250 non-null    object
#  1   email                           250 non-null    object
#  2   phone                           250 non-null    object
#  3   cell                            250 non-null    object
#  4   nat                             250 non-null    object
#  5   name.title                      250 non-null    object
#  6   name.first                      250 non-null    object
#  7   name.last                       250 non-null    object
#  8   location.street.number          250 non-null    int64
#  9   location.street.name            250 non-null    object
#  10  location.city                   250 non-null    object
#  11  location.state                  250 non-null    object
# ...

# %%
df
# Out:
#      gender                         email           phone            cell nat  \
# 0      male  bureviy.vdovenko@example.com  (068) U13-0030  (098) I97-9924  UA
# 1    female     meghan.horton@example.com  (389) 552-9360  (353) 453-6626  US
# 2      male      andre.barros@example.com  (63) 0017-4582  (80) 8574-8457  BR
# 3      male    marius.poulsen@example.com        25498451        38385601  DK
# 4    female    siiri.leinonen@example.com      08-279-158   041-985-06-55  FI
# ..      ...                           ...             ...             ...  ..
# 245  female    adele.fournier@example.com  01-50-72-35-43  06-75-69-60-42  FR
# 246  female         abbie.kim@example.com    019467 84906    07902 952542  GB
# 247  female         lia.dumas@example.com  02-64-72-51-92  06-41-44-07-66  FR
# 248    male  william.richards@example.com    015396 66853    07728 570216  GB
# 249  female     tilde.poulsen@example.com        54219911        81720906  DK
#
# ...

# %%
df.describe()
# Out:
#        location.street.number    dob.age  registered.age
# count              250.000000  250.00000      250.000000
# mean              4663.312000   50.38800       10.568000
# std               2977.592695   16.25887        5.904645
# min                 41.000000   23.00000        1.000000
# 25%               1877.500000   36.25000        5.250000
# 50%               4421.000000   49.00000       11.000000
# 75%               7221.250000   66.00000       15.000000
# max               9967.000000   78.00000       21.000000

# %%
df.shape
# Out:
# (250, 34)

# %%
mean = df['registered.age'].mean()
mean
# Out:
# 10.568

# %%
distCountries = df['nat'].unique()
distCountries
# Out:
# array(['UA', 'US', 'BR', 'DK', 'FI', 'ES', 'IN', 'NL', 'CA', 'RS', 'DE',
#        'GB', 'IR', 'IE', 'MX', 'TR', 'NZ', 'AU', 'FR', 'CH', 'NO'],
#       dtype=object)

# %%
count = len('distCountries')
count
# Out:
# 13

# %%
df[df['gender'] == 'male']
# Out:
#     gender                         email           phone            cell nat  \
# 0     male  bureviy.vdovenko@example.com  (068) U13-0030  (098) I97-9924  UA
# 2     male      andre.barros@example.com  (63) 0017-4582  (80) 8574-8457  BR
# 3     male    marius.poulsen@example.com        25498451        38385601  DK
# 7     male       rudra.uchil@example.com      9134098281      7818027742  IN
# 10    male  victor.jorgensen@example.com        01393286        29550025  DK
# ..     ...                           ...             ...             ...  ..
# 237   male        mhmd.zraay@example.com    012-34942738   0991-597-9068  IR
# 239   male    endre.olavesen@example.com        87188163        44065416  NO
# 241   male     berat.leijten@example.com   (032) 9586318   (06) 00335859  NL
# 243   male    harrison.jones@example.com  (707)-923-6720  (137)-202-2741  NZ
# 248   male  william.richards@example.com    015396 66853    07728 570216  GB
#
# ...

# %%
col34 = df.iloc[:, 2:4]
col34
# Out:
#               phone            cell
# 0    (068) U13-0030  (098) I97-9924
# 1    (389) 552-9360  (353) 453-6626
# 2    (63) 0017-4582  (80) 8574-8457
# 3          25498451        38385601
# 4        08-279-158   041-985-06-55
# ..              ...             ...
# 245  01-50-72-35-43  06-75-69-60-42
# 246    019467 84906    07902 952542
# 247  02-64-72-51-92  06-41-44-07-66
# 248    015396 66853    07728 570216
# 249        54219911        81720906
#
# [250 rows x 2 columns]

# %%
first4 = df.head(4)
first4
# Out:
#    gender                         email           phone            cell nat  \
# 0    male  bureviy.vdovenko@example.com  (068) U13-0030  (098) I97-9924  UA
# 1  female     meghan.horton@example.com  (389) 552-9360  (353) 453-6626  US
# 2    male      andre.barros@example.com  (63) 0017-4582  (80) 8574-8457  BR
# 3    male    marius.poulsen@example.com        25498451        38385601  DK
#
#   name.title name.first name.last  location.street.number  \
# 0         Mr    Bureviy  Vdovenko                     351
# 1        Mrs     Meghan    Horton                     818
# 2         Mr      André    Barros                    5867
# 3         Mr     Marius   Poulsen                    5803
#
#     location.street.name  ...  \
# 0  Lanzheronivskiy uzviz  ...
# 1              Nowlin Rd  ...
# 2               Rua Três  ...
# 3         Knudskovparken  ...
#
#                                         login.sha256  \
# 0  a57f0cdb326741e60fdc0126e8e54b764098987b7ae2df...
# ...
